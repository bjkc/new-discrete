# %% [markdown]
# <a href="https://colab.research.google.com/github/bjkc/new-discrete/blob/main/project5model5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROJECT5
# BIJAY RAJ KC.                 DISCRETE MATH
#
#
#
# Here to do this project i have choosen the iphone as i am using this phone with different model till now below i have listed all the iphone model till now.And i have always interested about the new iphone model the apple brings every year.

# %%
# !pip install anytree

# %%
from anytree import Node, RenderTree
from anytree.exporter import DotExporter
from IPython.display import display, Image
iphone = Node("iphone") #root
iphone2 = Node("IPHONE2", parent=iphone)
iphone2s = Node("IPHONE2S", parent=iphone)
iphone3s = Node("IPHONE3S", parent=iphone)
IPHONE4 = Node("IPHONE4", parent=iphone2s)
IPHONE4S = Node("IPHONE4S", parent=IPHONE4)
iphone5 = Node("IPHONE5", parent=IPHONE4)
iphone6 = Node("IPHONE6", parent=iphone5)
iphone6s = Node("IPHONE6S", parent=IPHONE4S)
iphone6plus = Node("IPHONE6PLUS", parent=iphone6)
iphone6splus = Node("IPHONE6SPLUS", parent=iphone6s)
iphone7 = Node("IPHONE7", parent=iphone6plus)
iphone7splus = Node("IPHONE7SPLUS", parent=iphone6plus)
iphone7Plus = Node("IPHONE7plus", parent=iphone7)
iphone8Plus = Node("IPHONE8PLUS", parent=iphone7splus)
iphonex = Node("IPHONEX", parent=iphone8Plus)
iphonexsmax = Node("IPHONEXSMAX", parent=iphonex)
iphone11 = Node("IPHONE11", parent=iphonexsmax)
iphone11pro = Node("IPHONE11PRO", parent=iphone11)
iphone11promax = Node("IPHONE11PROMAX", parent=iphone11)
iphone12 = Node("IPHONE12", parent=iphone11promax)
iphone12pro = Node("IPHONE12PRO", parent=iphone12)
iphone12proMAX = Node("IPHONE12PROMAX", parent=iphone12)
iphone13 = Node("IPHONE13", parent=iphone12proMAX)
iphone13pro = Node("IPHONE13PRO", parent=iphone13)
iphone13promax = Node("IPHONE13PROMAX", parent=iphone13)
DotExporter(iphone).to_picture("IPHONE.png")
display(Image("IPHONE.png"))

# %% [markdown]
# I was really having hard time while putting all the models in the  code in the parent section like iphone pro ,max,and s model and till now the latest iphone model is iphone 13promax.
